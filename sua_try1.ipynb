# %% [markdown]
# <a href="https://colab.research.google.com/github/suajeong52/collapsible_tube/blob/main/sua_try1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sciann
# Out:
# ...
#      |████████████████████████████████| 174 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 561 kB 50.2 MB/s
# ...
#      |████████████████████████████████| 460.3 MB 8.5 kB/s
# ...
#      |████████████████████████████████| 462 kB 64.1 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 36.3 MB/s
# ...
#      |████████████████████████████████| 14.8 MB 45.6 MB/s
# ...
#      |████████████████████████████████| 132 kB 54.5 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 51.0 MB/s
# ...
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68715 sha256=d9acb6643ce7b1d1d62d63c7814fb82fa5cc6a3fc40113dc5179d89127a0da63
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built wrapt
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.2.0
#     Uninstalling typing-extensions-4.2.0:
#       Successfully uninstalled typing-extensions-4.2.0
# ...

# %%
import numpy as np 
import sciann as sn 
import matplotlib.pyplot as plt  
from numpy import pi
from sciann.utils.math import diff, sign, sin, sqrt, pow

# %%
x = sn.Variable('x')
t = sn.Variable('t')
u = sn.Functional('u', [x,t], 8*[20], 'tanh')
A = sn.Functional('A', [x,t], 8*[20], 'tanh')

# %%
L1 = diff(A, t) + u*diff(A,x) + A * diff(u, x)

# %%
rho = 1
beta =200

L2 = diff(u, t) + u*diff(u,x) + beta/(2*rho*sn.pow(A*A+0.01,0.25) ) * diff(A, x, order=1)

# %%
TOL = 0.001
T = 10
omega = 2*np.pi/T
C1 = (1-sign(t - TOL)) * (u -0)
C2 = (1-sign(t - TOL)) * (A-1)
C3 = (1-sign(x - TOL)) * (u -sin(omega*t))

# %%
m = sn.SciModel([x, t], [L1,L2, C1, C2, C3])

# %%
x_data, t_data = np.meshgrid(
    np.linspace(0, 50, 100), 
    np.linspace(0, 120, 100)
)

# %%
h = m.train([x_data, t_data], 5*['zero'], learning_rate=0.002, epochs=1000, verbose=1)
# Out:
# Total samples: 10000
# Batch size: 64
# Total batches: 157
#
# Epoch 1/1000
# 157/157 [==============================] - 5s 6ms/step - batch: 78.0000 - size: 63.6943 - loss: 6.9817 - add_24_loss: 0.0026 - add_27_loss: 6.8366 - mul_50_loss: 0.0030 - mul_51_loss: 0.1034 - mul_53_loss: 0.0359 - lr: 0.0020 - time: 5.0336
# Epoch 2/1000
# 157/157 [==============================] - 1s 6ms/step - batch: 78.0000 - size: 63.6943 - loss: 0.3796 - add_24_loss: 8.5138e-04 - add_27_loss: 0.2372 - mul_50_loss: 0.0049 - mul_51_loss: 0.1112 - mul_53_loss: 0.0255 - lr: 0.0020 - time: 0.8849
# Epoch 3/1000
# 157/157 [==============================] - 1s 5ms/step - batch: 78.0000 - size: 63.6943 - loss: 1.1918 - add_24_loss: 0.0011 - add_27_loss: 1.0491 - mul_50_loss: 0.0011 - mul_51_loss: 0.1204 - mul_53_loss: 0.0201 - lr: 0.0020 - time: 0.8586
# Epoch 4/1000
# ...
